# %%
#TA_API_KEY: 38FE11C6EBEC4749ABE300D231742139

# %%
import requests
import pandas as pd

# %%
url = "https://api.content.tripadvisor.com/api/v1/location/189158/details?key=CBB35126EBD9459CA84EFE750511C8BA&language=en&currency=EUR"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {
#   "location_id": "189158",
#   "name": "Lisbon",
#   "description": "The museums of Lisbon celebrate the rich history and culture of this Portuguese capital city. The Maritime Museum is perfect for kids (and grown-ups!) who adore all things nautical, while the Casa-Museu Dr. Anastácio Gonçalves is a hidden gem of colorful artwork. To fully appreciate the city’s dramatic stone architecture you can take a guided walking tour, or customize your own tour, making sure to visit the Padrao dos Descobrimentos, the Mosteiro dos Jeronimos, and the UNESCO World Heritage site the Torre de Belem.  ",
#   "web_url": "https://www.tripadvisor.com/Tourism-g189158-Lisbon_Lisbon_District_Central_Portugal-Vacations.html?m=66827",
#   "address_obj": {
#     "city": "Lisbon District",
#     "country": "Portugal",
#     "address_string": "Lisbon Portugal"
#   },
#   "ancestors": [
#     {
#       "level": "District",
#       "name": "Lisbon District",
#       "location_id": "3874225"
#     },
#     {
# ...

# %% [markdown]
# # HOTELS IN LISBON:

# %%
import requests

url = "https://api.content.tripadvisor.com/api/v1/location/search?key=CBB35126EBD9459CA84EFE750511C8BA&searchQuery=Lisbon&category=hotels&language=en"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"message":"Missing Authentication Token"}

# %%
# Hotels in Lisbon

url = "https://api.content.tripadvisor.com/api/v1/location/search?key=CBB35126EBD9459CA84EFE750511C8BA&searchQuery=Lisbon&category=hotels&language=en"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {
#   "data": [
#     {
#       "location_id": "276952",
#       "name": "Corinthia Lisbon",
#       "address_obj": {
#         "street1": "Avenida Columbano Bordalo Pinheiro, 105",
#         "street2": "",
#         "city": "Lisbon",
#         "country": "Portugal",
#         "postalcode": "1099-031",
#         "address_string": "Avenida Columbano Bordalo Pinheiro, 105, Lisbon 1099-031 Portugal"
#       }
#     },
#     {
#       "location_id": "548451",
#       "name": "Bairro Alto Hotel",
#       "address_obj": {
#         "street1": "Praca Luis de Camoes 2",
#         "street2": "",
#         "city": "Lisbon",
#         "country": "Portugal",
#         "postalcode": "1200-243",
#         "address_string": "Praca Luis de Camoes 2, Lisbon 1200-243 Portugal"
#       }
#     },
#     {
#       "location_id": "12659702",
#       "name": "Corpo Santo Lisbon Historical Hotel",
#       "address_obj": {
#         "street1": "Largo do Corpo Santo, 25",
#         "city": "Lisbon",
# ...
